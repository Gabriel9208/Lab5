# %%
# Cell 1：掛載 Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
! uv run LAB5_B11030001_Code/dqn.py --task 3 --replay-start-size 40000 --epsilon-decay 0.999999 --lr 0.00025 --epsilon-min 0.1 --target-update-frequency 10000  --wandb-run-name task3_DDQN --episodes 5000 --memory-size 50000 --save-dir /content/drive/MyDrive/LAB5_results --dqn-type DDQN
